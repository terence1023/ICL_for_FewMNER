# %%
import numpy as np
class InputExample(object):
    def __init__(self, text_a, text_b=None, label_aspect=None, image_id=None):
        self.text_a = text_a
        self.text_b = text_b
        self.label_aspect = label_aspect
        self.image_id = image_id

def read_mner(text_path):
    load_file = text_path
    examples = []
    count = 0
    with open(load_file, "r", encoding="utf-8") as f:
        lines = f.readlines()
        raw_words, raw_targets = [], []
        raw_word, raw_target = [], []
        imgs = []
        for line in lines:
            if line.startswith("IMGID:"):
                img_id = line.strip().split('IMGID:')[1] + '.jpg'
                imgs.append(img_id)
                continue
            if line != "\n":
                raw_word.append(line.split('\t')[0])
                label = line.split('\t')[1][:-1]
                if 'OTHER' in label:
                    label = label[:2] + 'MISC'
                raw_target.append(label)
            else:
                assert len(raw_word) == len(raw_target)
                raw_words.append(raw_word)
                raw_targets.append(raw_target)
                # guid = "%s-%s" % (set_type, count)
                text_a = ' '.join(raw_word)
                tags = raw_target
                image_path_single = str(img_id)
                count += 1
                examples.append(
                    InputExample(text_a=text_a, text_b=None, label_aspect=tags, image_id=image_path_single)
                )
                raw_word, raw_target = [], []
    return examples

# %%
def ts2bio(ts_tag_sequence):
    
    new_ts_sequence = []
    n_tags = len(ts_tag_sequence)
    for i in range(n_tags):
        ts_tag = ts_tag_sequence[i]
        if ts_tag == 'O' or ts_tag == 'EQ':
            new_ts_sequence.append('O')
        else:
            new_ts_sequence.append(ts_tag)
    return new_ts_sequence

def bio2bioes_ts(ts_tag_sequence):
    n_tags = len(ts_tag_sequence)
    new_ts_sequence = []
    for i in range(n_tags):
        cur_ts_tag = ts_tag_sequence[i]
        if cur_ts_tag == 'O' or cur_ts_tag == 'EQ':
            # when meet the EQ label, regard it as O label
            new_ts_sequence.append('O')
        else:
            cur_pos, cur_sentiment = cur_ts_tag.split('-')
            if cur_pos == 'B':
                if (i == n_tags - 1) or (ts_tag_sequence[i+1].split('-')[0] != 'I'):
                    new_ts_sequence.append('S-%s' % cur_sentiment)
                else:
                    new_ts_sequence.append('B-%s' % cur_sentiment)
            elif cur_pos == 'I':
                # if (i == n_tags - 1) or (ts_tag_sequence[i+1].split('-')[0] != 'I'):
                # 少考虑这种情况：[O, O, I, O, B, I, I, O, O]
                # 第一个I，如果按照原来的规则，会被标记为E
                if (i == n_tags - 1) or (ts_tag_sequence[i + 1].split('-')[0] != 'I' and i != 0 and ts_tag_sequence[i - 1].split('-')[0] != 'O'):
                    new_ts_sequence.append('E-%s' % cur_sentiment)
                else:
                    new_ts_sequence.append('I-%s' % cur_sentiment)
    return new_ts_sequence

def tag2ts(ts_tag_sequence):
    """
    transform ts tag sequence to targeted sentiment
    :param ts_tag_sequence: tag sequence for ts task
    :return:
    """
    n_tags = len(ts_tag_sequence)
    ts_sequence, sentiments = [], []
    beg, end = -1, -1
    for i in range(n_tags):
        ts_tag = ts_tag_sequence[i]
        # current position and sentiment
        # tag O and tag EQ will not be counted
        eles = ts_tag.split('-')
        if len(eles) == 2:
            pos, sentiment = eles
        else:
            pos, sentiment = 'O', 'O'
        if sentiment != 'O':
            # current word is a subjective word
            sentiments.append(sentiment)
        if pos == 'S':
            # singleton
            ts_sequence.append((i, i, sentiment))
            sentiments = []
        elif pos == 'B':
            beg = i
            if len(sentiments) > 1:
                # remove the effect of the noisy I-{POS,NEG,NEU}
                sentiments = [sentiments[-1]]
        elif pos == 'E':
            end = i
            # schema1: only the consistent sentiment tags are accepted
            # that is, all of the sentiment tags are the same
            if end > beg > -1 and len(set(sentiments)) == 1:
                ts_sequence.append((beg, end, sentiment))
                sentiments = []
                beg, end = -1, -1
    return ts_sequence

# %%
# multi entities
import pandas as pd
def data_to_pandas(examples):
    pd_test = pd.DataFrame(columns=["text", "entity_category", "image_id", "person", "location", "organization", "miscellaneous"])
    per_count, loc_count, org_count, misc_count = 0, 0, 0, 0
    for i in range(len(examples)):
        text = examples[i].text_a
        label_aspect = examples[i].label_aspect
        image_id = examples[i].image_id
        tags = bio2bioes_ts(ts2bio(label_aspect))
        ts_sequence = tag2ts(ts_tag_sequence=tags)
        text_list = text.split(" ")
        entity_list,category_list = [], []
        person_list, location_list, org_list, misc_list = [], [], [], []
        for ner in ts_sequence:
            entity = " ".join(text_list[ner[0]:ner[1]+1])
            category = ner[-1]
            if category == "MISC":
                category = "miscellaneous"
                misc_list.append(entity)
                misc_count += 1
            elif category == "LOC":
                category = "location"
                location_list.append(entity)
                loc_count += 1
            elif category == "ORG":
                category = "organization"
                org_list.append(entity)
                org_count += 1
            elif category == "PER":
                category = "person"
                person_list.append(entity)
                per_count += 1
            else:
                raise ValueError("error category")
            entity_list.append(entity)
            category_list.append(category)
        entity_category = []
        for j in range(len(entity_list)):
            entity_category.append((entity_list[j], category_list[j]))
        pd_test.loc[i, "text"] = text
        pd_test.loc[i, "entity_category"] = entity_category
        pd_test.loc[i, "image_id"] = image_id
        
        # "person", "location", "organization", "miscellaneous"
        pd_test.loc[i, "person"] = person_list
        pd_test.loc[i, "location"] = location_list
        pd_test.loc[i, "organization"] = org_list
        pd_test.loc[i, "miscellaneous"] = misc_list
    print("per_count", per_count)
    print("loc_count", loc_count)
    print("org_count", org_count)
    print("misc_count", misc_count)
    return pd_test

train_path = "../dataset/mner/twitter2017/train.txt"
dev_path = "../dataset/mner/twitter2017/dev.txt"
test_path = "../dataset/mner/twitter2017/test.txt"

train_examples = read_mner(train_path)
dev_examples = read_mner(dev_path)
test_examples = read_mner(test_path)

pd_train = data_to_pandas(examples=train_examples)
pd_dev = data_to_pandas(examples=dev_examples)
pd_test = data_to_pandas(examples=test_examples)

print(len(pd_train), len(pd_dev), len(pd_test))
# Out:
# per_count 2943
# loc_count 731
# org_count 1674
# misc_count 701
# per_count 626
# loc_count 173
# org_count 375
# misc_count 150
# per_count 621
# loc_count 178
# org_count 395
# misc_count 157
# 3373 723 723

# %%
type(pd_train.loc[0, "person"])
# Out:
# list

# %%
# save processed files
pd_train.to_csv("twitter2017_process_train.csv", index=False, sep='\t')
pd_dev.to_csv("twitter2017_process_dev.csv", index=False, sep='\t')
pd_test.to_csv("twitter2017_process_test.csv", index=False, sep='\t')

# %%
read_test = pd.read_csv("twitter2017_process_train.csv",sep='\t')

# %%
read_test.head(20)
# Out:
#                                                  text  \
# 0         New Post : Blackburn Festival of Voice 2017
# 1   # NBA : Kawhi Leonard wins the fan vote for Bl...
# 2   Justin Bieber , Rich the Kid and Diplo have a ...
# 3            New Event : French Quarter Festival 2020
# 4   Eric Nam announces concert dates for Atlanta a...
# 5   Rough Riders baseball and Degan 5 th graders !...
# 6   People lining up outside KeyArena . Still abou...
# 7   If you ' re not at the SHS band concert you ' ...
# 8              @ hannuhnell after the rihanna concert
# 9   I have a number of events planed , charity foo...
# 10  Podcast : Cavs - Warriors Game 3 recap # Caval...
# 11        which should i wear to my soccer banquet xx
# 12  The trailer for James Franco ' s ' revamped ' ...
# 13  48 years ago today we won our very first @ Bun...
# 14  Let ' s go for all @ warriors 💪 🏀 🏀 for Erik #...
# 15  Some love from @ ETSUFootball . Looking forwar...
# 16  Join us tonight at @ pizzaportCbad for the Civ...
# 17  Bill of Rights 200 th Anniversary First Day of...
# 18  From Pride Parade in Paris , 2015 . # dogsofpride
# 19  Marc Chagall - 1944 , The House with the Green...
#
#                                       entity_category          image_id  \
# 0   [('Blackburn Festival of Voice', 'miscellaneou...   17_06_12483.jpg
# 1   [('NBA', 'organization'), ('Kawhi Leonard', 'p...    17_06_2932.jpg
# 2   [('Justin Bieber', 'person'), ('Rich the Kid',...        O_1926.jpg
# 3      [('French Quarter Festival', 'miscellaneous')]  16_05_24_704.jpg
# 4   [('Eric Nam', 'person'), ('Atlanta', 'location...   17_06_12486.jpg
# 5   [('Rough Riders', 'organization'), ('Degan', '...  16_05_23_627.jpg
# 6   [('KeyArena', 'location'), ('Seattle', 'locati...  16_05_28_123.jpg
# 7                           [('SHS', 'organization')]  16_05_05_133.jpg
# 8   [('hannuhnell', 'person'), ('rihanna', 'person')]  16_05_17_498.jpg
# 9                                                  []  16_05_10_969.jpg
# 10  [('Cavs', 'organization'), ('Warriors', 'organ...    17_06_7980.jpg
# 11                                                 []   17_06_11757.jpg
# 12  [('James Franco', 'person'), ('Mother , May I ...        O_3127.jpg
# 13                [('Bundesliga_EN', 'organization')]    17_06_1239.jpg
# 14  [('warriors', 'organization'), ('Erik', 'perso...   17_06_13987.jpg
# 15                 [('ETSUFootball', 'organization')]    17_06_1237.jpg
# 16  [('pizzaportCbad', 'location'), ('FirestoneWal...   16_05_28_46.jpg
# 17                                                 []        O_2548.jpg
# 18                            [('Paris', 'location')]    17_06_5383.jpg
# 19  [('Marc Chagall', 'person'), ('The House with ...        O_2369.jpg
#
#                                         person                 location  \
# 0                                           []                       []
# 1                            ['Kawhi Leonard']                       []
# 2   ['Justin Bieber', 'Rich the Kid', 'Diplo']                       []
# 3                                           []                       []
# 4                                 ['Eric Nam']       ['Atlanta', 'NYC']
# 5                                           []                       []
# 6                                           []  ['KeyArena', 'Seattle']
# 7                                           []                       []
# 8                    ['hannuhnell', 'rihanna']                       []
# 9                                           []                       []
# 10                                          []                       []
# 11                                          []                       []
# 12                            ['James Franco']                       []
# 13                                          []                       []
# 14                                    ['Erik']                       []
# 15                                          []                       []
# 16                                          []        ['pizzaportCbad']
# 17                                          []                       []
# 18                                          []                ['Paris']
# 19                            ['Marc Chagall']                       []
#
#                                 organization  \
# 0                                         []
# 1                                    ['NBA']
# 2                                         []
# 3                                         []
# 4                                         []
# 5                  ['Rough Riders', 'Degan']
# 6                                         []
# 7                                    ['SHS']
# 8                                         []
# 9                                         []
# 10  ['Cavs', 'Warriors', 'Cavaliers', 'NBA']
# 11                                        []
# 12                                        []
# 13                         ['Bundesliga_EN']
# 14                              ['warriors']
# 15                          ['ETSUFootball']
# 16     ['FirestoneWalker', 'GreenFlashBeer']
# 17                                        []
# 18                                        []
# 19                                        []
#
#                            miscellaneous
# 0        ['Blackburn Festival of Voice']
# 1                          ['NBAAwards']
# 2                                     []
# 3            ['French Quarter Festival']
# 4                                     []
# 5                                     []
# 6                                     []
# 7                                     []
# 8                                     []
# 9                                     []
# 10                                    []
# 11                                    []
# 12  ['Mother , May I Sleep with Danger']
# 13                                    []
# 14                                    []
# 15                                    []
# 16                                    []
# 17                                    []
# 18                                    []
# 19      ['The House with the Green Eye']
